# %%
#@title
#
# Template for python program
# Name:
#

import matplotlib.pyplot as plt
import numpy as np

# %%
# 1. Input
xpoints= np.array([0,10])
ypoint= np.array([0,250])

# %%
# 3. Output
plt.title("Line Between Two Point: Michael")
plt.plot(xpoints,ypoint)
plt.show()
